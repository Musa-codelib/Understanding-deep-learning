# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
# Define your training data and labels
train_data = [
    "This is a great product!",
    "I am very happy with this service.",
    "I don't like this at all.",
    "The movie was fantastic.",
]

train_labels = ["positive", "positive", "negative", "positive"]

# %%
# Create TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Fit and transform the training data
X_train = vectorizer.fit_transform(train_data)

# %%
# Train a classifier (e.g., Multinomial Naive Bayes)
classifier = MultinomialNB()
classifier.fit(X_train, train_labels)
# Out:
# MultinomialNB()

# %%
# Preprocess and predict sentiments for new text data
new_texts = [
    "I love this product, it's amazing!",
    "This movie is terrible, I regret watching it.",
    "The weather today is so-so.",
]
preprocessed_texts = [preprocess_text(text) for text in new_texts]
X_new = vectorizer.transform(preprocessed_texts)
predicted_sentiments = classifier.predict(X_new)

# %%
# Apply a threshold to the predicted probabilities
predicted_probabilities = classifier.predict_proba(X_new)
threshold = 0.5
final_sentiments = ["positive" if prob >= threshold else "negative" for prob in predicted_probabilities[:, 1]]

# %%
# Evaluate the accuracy of the sentiment predictions
true_labels = ["positive", "negative", "neutral"]  # Define the true labels for new texts
accuracy = accuracy_score(true_labels, final_sentiments)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3333333333333333
